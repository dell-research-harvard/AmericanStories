# %% [markdown]
# # Preamble
#
# Welcome to American Stories! Please run the next two cells (hint: hold Shift and press Enter three times) to install the required packages, and then we move to working with the American Stories dataset.

# %%
###Installs
# !pip install datasets
# !pip install ipympl
# Out:
# Collecting datasets
#   Downloading datasets-2.14.5-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 8.1 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.5)
# Collecting huggingface-hub<1.0.0,>=0.14.0 (from datasets)
#   Downloading huggingface_hub-0.17.1-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 12.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, dill, multiprocess, huggingface-hub, datasets
# Successfully installed datasets-2.14.5 dill-0.3.7 huggingface-hub-0.17.1 multiprocess-0.70.15 xxhash-3.3.0
# Collecting ipympl
#   Downloading ipympl-0.9.3-py2.py3-none-any.whl (511 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.6/511.6 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: ipython<9 in /usr/local/lib/python3.10/dist-packages (from ipympl) (7.34.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ipympl) (1.23.5)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipympl) (0.2.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from ipympl) (9.4.0)
# Requirement already satisfied: traitlets<6 in /usr/local/lib/python3.10/dist-packages (from ipympl) (5.7.1)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /usr/local/lib/python3.10/dist-packages (from ipympl) (7.7.1)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from ipympl) (3.7.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl) (67.7.2)
# Collecting jedi>=0.16 (from ipython<9->ipympl)
#   Downloading jedi-0.19.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.7 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl) (4.8.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9,>=7.6.0->ipympl) (5.5.6)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.6.5)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.4.0->ipympl) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.4.0->ipympl) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.4.0->ipympl) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.4.0->ipympl) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython<9->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<9->ipympl) (0.2.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (6.5.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (3.1.2)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (5.3.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.5.7)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.0.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (3.10.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.2.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.1.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.18.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (4.19.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.10.2)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.6.2)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.21)
# Installing collected packages: jedi, ipympl
# Successfully installed ipympl-0.9.3 jedi-0.19.0

# %%
#Imports
import json

from datasets import load_dataset
import tqdm as tq

# %% [markdown]
# # Introduction
#
# Welcome to the intro notebook to AmericanStories. This is an expanded version of the intro notebook available here: https://colab.research.google.com/drive/1ifzTDNDtfrrTy-i7uaq3CALwIWa7GB9A?ts=648b98bf.
#
# In this notebook, we will do three things:
#
# 1. Discuss ways to import the data
# 2. Explore the way the data is structured, and show simple code snippets for accessing the data
# 3. Provide three applications that would not be possible with keyword search based methods:
#
# A. We show how to find out whether an *article* mentions two terms simultaneously
#
# B. We show how to find out what other articles on a page with a keyword hit
# discuss
#
# C. We showcase a wire-cluster pipeline. Wire-clusters are same/similar articles
# that originate in a article that went out over the newswire. With this you
# can measure which places were exposed to the same newpaper content

# %% [markdown]
# # Part I: importing data
#
# There are four main ways of accessing the American Stories data. A key contribution of our project is to make *articles* available, which requires linking together disjoint content regions. To take full advantange of this, we provide access to the data at the article level, or at the level of a scan, that is, one page of one edition of a single newspaper. For both ways, you can either query by year, or get a dump of all data. In sum, the four ways of interacting with our data:
#
# a. Article level, for selected years
#
# b. Article level, for all years
#
# c. Scan level, for selected years
#
# d. Scan level, for all years

# %% [markdown]
# ### 1a: Article, level, for selected years
#
# We will now select all articles for the year 1900. Below we will explore the resulting dataset in detail

# %%
# let's start with deciding which years we want data for
article_level_desired_years = ["1900", ]

# now let's load our data, we have to specify the huggingface location of our
# data, the fact that we want to have a subset of years, and our desired years
dataset_article_level=load_dataset("dell-research-harvard/AmericanStories",
                                   "subset_years",
                                   year_list=article_level_desired_years
                                   )
# Out:
# Downloading builder script:   0%|          | 0.00/8.91k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/8.02k [00:00<?, ?B/s]
# Only taking a subset of years. Change name to 'all_years' to use all years in the dataset.
# {'1900': 'https://huggingface.co/datasets/dell-research-harvard/AmericanStories/resolve/main/faro_1900.tar.gz'}
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/1.68G [00:00<?, ?B/s]
# Generating 1900 split: 0 examples [00:00, ? examples/s]
# Loading associated

# %% [markdown]
# ### 1b: article level, for all years
# The next cell contains to get all articles for all years. It is commented because running it requires a lot of bandwidth and data. Please uncomment, and then run to get all data

# %%
# Uncomment the next line and execute this cell to download the entire dataset
#dataset_article_level_all_years = load_dataset("dell-research-harvard/AmericanStories", "all_years")

# %% [markdown]
# ### 1c: scan level, for selected years
# The next cell contains to get all scans for selected years.

# %%
# let's start with deciding which years we want data for
scan_level_desired_years = ["1900",]

# now let's load our data, we have to specify the huggingface location of our
# data, the fact that we want to have a subset of years, and our desired years
dataset_scan_level=load_dataset("dell-research-harvard/AmericanStories",
                                "subset_years_content_regions",
                                year_list=scan_level_desired_years
                                )
# Out:
# {'1900': 'https://huggingface.co/datasets/dell-research-harvard/AmericanStories/resolve/main/faro_1900.tar.gz'}
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating 1900 split: 0 examples [00:00, ? examples/s]

# %% [markdown]
# ### 1d: scan level, for all years
# The next cell contains to get all scans for all years. It is commented because running it requires a lot of bandwidth and data. Please uncomment, and then run to get all data

# %%
# Uncomment the next line and execute this cell to download the entire dataset
#dataset_scan_level_all_years = load_dataset("dell-research-harvard/AmericanStories", "all_years")

# %% [markdown]
# # Part II: Exploring the data, with applications
#
# We will do three things in the next section:
#
# 1. Discuss the structure of the returned dataset
# 2. Discuss how to access the data
# 3. Implement our applications

# %% [markdown]
# ### IIa: Article level

# %%
# let's inspect the structure
print(dataset_article_level)
# Out:
# DatasetDict({
#     1900: Dataset({
#         features: ['article_id', 'newspaper_name', 'edition', 'date', 'page', 'headline', 'byline', 'article'],
#         num_rows: 1118970
#     })
# })

# %%
# We see that we have 1.1mln articles for 1900, and that we have several self-explanatory features for each article. Let's explore the data

# %%
# the structure of the output is a dictionary. The keys of the dictionary are the fields we have for each article
dataset_article_level["1900"].features
# Out:
# {'article_id': Value(dtype='string', id=None),
#  'newspaper_name': Value(dtype='string', id=None),
#  'edition': Value(dtype='string', id=None),
#  'date': Value(dtype='string', id=None),
#  'page': Value(dtype='string', id=None),
#  'headline': Value(dtype='string', id=None),
#  'byline': Value(dtype='string', id=None),
#  'article': Value(dtype='string', id=None)}

# %%
# let's inspect a random article from 1900
dataset_article_level["1900"][5]
# Out:
# {'article_id': '7_1900-03-23_p6_sn83045462_00280655326_1900032301_0034',
#  'newspaper_name': 'Evening star.',
#  'edition': '01',
#  'date': '1900-03-23',
#  'page': 'p6',
#  'headline': 'Young Folks\nSpring Shoes.',
#  'byline': '',
#  'article': "Our stock of Shoes for young peo-\npie comprises the best and most rep\nutable goods manufactured. All the\nlatest and most improved shapes are\nrepresented, and both service and\nappearance were considered i'll their\nselection. We are also showing the\nLow Shoes for misses and children,\nin welt and turn sole, patent leather.\nvici kid and Russia calf; and the Nici\nKid Spring Heel Shoes with patent\ntips, in extra sizes (21a to 51a). At\ntention is also called to our lines Of\nInfants Cacks and Soft Sole Shoes,\nin black, tans and other colors.\n\n\nThe spring styles are ready.\n\n\nYouths Shoes sizes II to . Pair. 81 so to 50. 80\nBoys Shoes; sizes 21a 5h. Pair S15O to IS 90\nMisses Shoes; sizes II to p Pair .s15O to $500\nChiliren's Shoes; sizes sls to 1Ol9 Pair\n\n\nS1.25 to s.. 90\nInfants Shoes: sizes 6 to s. Pair 81 90 to 81 II\nInfants Cacks; sizes 2 TO g. Pair soc. to 81 %\nMisses OYford5: sizes II to .. Pair. 81 50\nMisses Springfield Oxfords extra sizes, 2H to\noi2. Falr -SZ.oo\nChiiren's O1fords; sizes SA, to 1oR Pair. 81 SO\nInfants oxfords sizes to S. Pair. 81 80\nThird floor"}

# %%
# we can see the headline, and that this appeared in the Evening star. Below we will learn more about the Evening star. For now, let's inspect the article
print(dataset_article_level["1900"][5]["article"])
# Out:
# Our stock of Shoes for young peo-
# pie comprises the best and most rep
# utable goods manufactured. All the
# latest and most improved shapes are
# represented, and both service and
# appearance were considered i'll their
# selection. We are also showing the
# Low Shoes for misses and children,
# in welt and turn sole, patent leather.
# vici kid and Russia calf; and the Nici
# Kid Spring Heel Shoes with patent
# tips, in extra sizes (21a to 51a). At
# tention is also called to our lines Of
# Infants Cacks and Soft Sole Shoes,
# in black, tans and other colors.
#
#
# The spring styles are ready.
#
#
# Youths Shoes sizes II to . Pair. 81 so to 50. 80
# Boys Shoes; sizes 21a 5h. Pair S15O to IS 90
# Misses Shoes; sizes II to p Pair .s15O to $500
# Chiliren's Shoes; sizes sls to 1Ol9 Pair
#
#
# S1.25 to s.. 90
# Infants Shoes: sizes 6 to s. Pair 81 90 to 81 II
# Infants Cacks; sizes 2 TO g. Pair soc. to 81 %
# Misses OYford5: sizes II to .. Pair. 81 50
# Misses Springfield Oxfords extra sizes, 2H to
# oi2. Falr -SZ.oo
# Chiiren's O1fords; sizes SA, to 1oR Pair. 81 SO
# Infants oxfords sizes to S. Pair. 81 80
# Third floor

# %%
# it is easy to loop through articles and see if it mentions 'spring style'
# here we will loop through the first ten articles

# let's initialize a dict for our articles. Let's collect the index of the
# article that contains our desired string as well as the article_id in case
# we want to find articles back later
dict_of_articles_containing_spring_style = {}

# we are interesting in spring style
str_of_interest = "spring style"

# let's loop!
for article_n in range(10):

  # let's grab the article data
  article = dataset_article_level["1900"][article_n]

  # let's grab the article text
  article_text = article["article"]

  # check if we see the text
  if str_of_interest in article_text:
    dict_of_articles_containing_spring_style[article_n] = article["article_id"]
  else:
    pass

# let's see which articles feature this text
print(dict_of_articles_containing_spring_style)
# Out:
# {5: '7_1900-03-23_p6_sn83045462_00280655326_1900032301_0034'}

# %% [markdown]
# ## Application: Two strings within the *same article*
#
# Previous methods for querying historical newspapers often relied on keyword
# searches.
#
# This made it impossible to verify if the same *article* mentioned
# two terms.
#
# Our dataset allows this, let's work through a simple example

# %%
# let's see if we can see if an article mentions both spring style
# and infants shoes
str_of_interest_1 = "spring style"
str_of_interest_2 = "infants shoes"

# we want to find articles back later
dict_of_articles_containing_spring_style_infants_shoes = {}

# proceed like before, restricting ourselves to the first 10 articles
for article_n in range(10):

  # let's grab the article data
  article = dataset_article_level["1900"][article_n]

  # let's grab the article text. We need to worry about capitalization here
  article_text = article["article"].lower()

  # we now test for both strings being present
  if (
      str_of_interest_1 in article_text
      and
      str_of_interest_2 in article_text
  ):
    dict_of_articles_containing_spring_style_infants_shoes[article_n] = (
        article["article_id"]
    )
  else:
    pass

# let's see which articles feature this text
print(dict_of_articles_containing_spring_style_infants_shoes)
# Out:
# {5: '7_1900-03-23_p6_sn83045462_00280655326_1900032301_0034'}

# %%
dataset_article_level
# Out:
# DatasetDict({
#     1900: Dataset({
#         features: ['article_id', 'newspaper_name', 'edition', 'date', 'page', 'headline', 'byline', 'article'],
#         num_rows: 1118970
#     })
# })

# %%
# in our article we found that the Boer War was the biggest story. We can
# see which articles mention both the Boer War, and Winston Churchill who
# was there as a report. Let's try with all articles this time
str_of_interest_1 = "boer"
str_of_interest_2 = "churchill"

# we want to find articles back later
dict_of_articles_containing_boer_war_churchill = {}

# proceed like before, looping through all articles. This should take 3 to 4 min
for article_n in tq.tqdm(range(1118970)):

  # let's grab the article data
  article = dataset_article_level["1900"][article_n]

  # let's grab the article text. We need to worry about capitalization here
  article_text = article["article"].lower()

  # we now test for both strings being present
  if (
      str_of_interest_1 in article_text
      and
      str_of_interest_2 in article_text
  ):
    dict_of_articles_containing_boer_war_churchill[article_n] = (
        article["article_id"]
    )
  else:
    pass
# Out:
# 100%|██████████| 1118970/1118970 [02:30<00:00, 7426.09it/s]

# %%
# let's see how many articles we got
print(len(dict_of_articles_containing_boer_war_churchill))

# let's print the results
print(dict_of_articles_containing_boer_war_churchill)
# Out:
# 122
# {676: '12_1900-12-15_p25_sn83045462_00280655375_1900121501_0335', 700: '56_1900-12-15_p25_sn83045462_00280655375_1900121501_0335', 5538: '3_1900-05-12_p1_sn86072192_00340583395_1900051201_0370', 8451: '29_1900-02-01_p3_sn88053087_00271741613_1900020101_0128', 9524: '10_1900-01-03_p1_sn86072192_00340583383_1900010301_0020', 14931: '21_1900-03-08_p1_sn90059523_00206533985_1900030801_0075', 39000: '5_1900-03-01_p1_sn86072192_00340583383_1900030101_0524', 43128: '32_1900-03-04_p23_sn83030214_00175040833_1900030401_0070', 43143: '24_1900-03-04_p23_sn83030214_00175040833_1900030401_0070', 43644: '10_1900-12-12_p7_sn83030214_0017504095A_1900121201_0227', 46674: '15_1900-05-04_p1_sn86072192_00340583395_1900050401_0306', 47314: '8_1900-04-25_p1_sn86072192_00340583395_1900042501_0226', 47325: '19_1900-04-25_p1_sn86072192_00340583395_1900042501_0226', 50899: '3_1900-02-10_p1_sn84020358_0041566820A_1900021001_0361', 51959: '57_1900-12-16_p12_sn86072192_00340583127_1900121601_0727', 51964: '66_1900-12-16_p12_sn86072192_00340583127_1900121601_0727', 60483: '4_1900-01-23_p5_sn99021999_0020653946A_1900012301_0453', 105630: '2_1900-07-18_p2_sn86063147_00279528256_1900071801_0459', 112373: '3_1900-03-03_p1_sn84020358_0041566820A_1900030301_0529', 114121: '13_1900-03-21_p1_sn86072192_00340583383_1900032101_0720', 133428: '8_1900-11-25_p20_sn83030214_00175040948_1900112501_0455', 147112: '11_1900-03-06_p1_sn86072192_00340583383_1900030601_0572', 148217: '13_1900-02-17_p1_sn84022991_00513688209_1900021701_0025', 164454: '5_1900-04-16_p1_sn83030214_00175040857_1900041601_0320', 179265: '35_1900-02-10_p1_sn86072192_00340583383_1900021001_0348', 190808: '22_1900-03-01_p2_sn84002889_00513681045_1900030101_0201', 191280: '18_1900-04-05_p1_sn83045462_00280655326_1900040501_0231', 199596: '70_1900-02-22_p1_sn84020358_0041566820A_1900022201_0457', 202493: '8_1900-01-05_p1_sn89052133_00383341152_1900010501_0481', 205481: '15_1900-04-20_p2_sn85025620_00212479603_1900042001_0119', 210600: '5_1900-03-18_p1_sn86072192_00340583383_1900031801_0684', 219673: '27_1900-01-26_p3_sn83025493_00220720457_1900012601_0003', 227949: '13_1900-03-21_p1_sn84020358_0041566820A_1900032101_0677', 236524: '22_1900-02-08_p1_sn82016187_0010049372A_1900020801_0380', 245220: '18_1900-12-09_p7_sn83030214_0017504095A_1900120901_0158', 249704: '11_1900-01-05_pNone_sn83030214_0017504081A_1900010501_0052', 250947: '16_1900-11-16_p8_sn84022960_00414212037_1900111601_1157', 265374: '4_1900-04-25_pNone_sn90059523_00206533985_1900042501_0646', 269204: '22_1900-03-18_pNone_sn90059523_00206533985_1900031801_0173', 296056: '33_1900-05-04_p1_sn84020358_0041566820A_1900050401_1053', 304345: '4_1900-12-03_p4_sn86072192_00340583127_1900120301_0603', 315746: '51_1900-05-04_p2_sn84020274_0021110904A_1900050401_0046', 318633: '39_1900-03-01_p3_sn88053055_00271741248_1900030101_0219', 320977: '19_1900-12-03_p2_sn82014248_00514156074_1900120301_0466', 324229: '4_1900-05-02_p1_sn83030214_00175040869_1900050201_0018', 324232: '7_1900-05-02_p1_sn83030214_00175040869_1900050201_0018', 342120: '4_1900-02-15_p2_sn83016025_00414210752_1900021501_0983', 342123: '7_1900-02-15_p2_sn83016025_00414210752_1900021501_0983', 349974: '25_1900-05-31_p3_sn83030214_00175040869_1900053101_0582', 352526: '64_1900-01-05_p1_sn82014248_00514156049_1900010501_0039', 366009: '4_1900-12-15_p1_sn83030214_0017504095A_1900121501_0263', 387551: '8_1900-05-18_p8_sn88076095_00199918485_1900051801_0221', 391468: '31_1900-05-04_p1_sn90059523_00206533997_1900050401_0035', 399567: '40_1900-02-02_pNone_sn83045462_00280655314_1900020201_0130', 408285: '23_1900-03-06_p1_sn84024441_100492003_1900030601_0398', 411263: '60_1900-02-23_p8_sn84022960_00414212037_1900022301_0853', 414370: '36_1900-01-02_p6_sn83030214_0017504081A_1900010201_0017', 416259: '4_1900-05-02_p2_sn86072192_00340583395_1900050201_0291', 444167: '44_1900-06-30_p8_sn83045462_00280655338_1900063001_0730', 465363: '17_1900-05-26_p8_sn83030214_00175040869_1900052601_0483', 475694 ...

# %%
# let's inspect the first one
dataset_article_level["1900"][5538]

# this article is from the Age Herald from May 12th, and describes the progress of the war
# Out:
# {'article_id': '3_1900-05-12_p1_sn86072192_00340583395_1900051201_0370',
#  'newspaper_name': 'The age-herald.',
#  'edition': '01',
#  'date': '1900-05-12',
#  'page': 'p1',
#  'headline': 'Lord Roberts Continues His\n\n March to KroonStadt.\n\nIS HOW WITHIN TWENTY MILES\n\nHundreds of the British Troopers Sank Into Watery Grave While Att tempting to Cross the\n\n Vaal River',
#  'byline': '',
#  'article': 'London, May 12-i a. m.-A British cole Imn 300O strong has arrived at VrybGrg, 1DG miles from Mafeking. It reached there Thursday. and although harassed by the Boers, is pushing swiftly forward. Fifty miles south of Vryburg, at Taungs, is Gen eral Hunters main body moving slowly and tending with considerable forces. The pick of his mounted men are the 5000 who are going with wheeled transport and at q rate that possibly bring them to Mafeking on Monday or Tuesday next.\n\n Lord Roberts narrative closes with Thursday evening, but he continued his march toward kroonstadt, twenty miles distant, and by this time he must know whether the Boers intend to fight there.\n\n Mir. Winston Churchill says there were only 20O0 Boers who opposed the British at Zard river. Another estimate is that 6oo0 naers with six guns made rear guard ac- tion. while many other thousands wlth conveys retired without firing shot\n\n President Steyn and council of the leaders of several thousand Free Staters in the Lady Brand and Ficksburg distrlct determined to submit to the men the ques- tier. of continuing the war or not at great open-air meeting. The fighting men decided to fight on. Steyn, who appears to be Tn active command, began to advance toward the British and came in contact on Thurs d;y with Calnpbels brigade and Brabants s Horse twenty miles northeast of Thaba Gnu. A smart engagement ensued wlth no positive success either side except that the Boer advance was stopped. Gen eral Bundle has placed 10000 infantry along a twenty mile front in such way as to oar Boer advance toward Lord Roberts com munications.\n\n According to a Pretoria telegram General Butler is moving from Elandslaagte In the direction of Helpmakar.'}

# %%
# let's print the article
print(dataset_article_level["1900"][5538]["article"])
# Out:
# London, May 12-i a. m.-A British cole Imn 300O strong has arrived at VrybGrg, 1DG miles from Mafeking. It reached there Thursday. and although harassed by the Boers, is pushing swiftly forward. Fifty miles south of Vryburg, at Taungs, is Gen eral Hunters main body moving slowly and tending with considerable forces. The pick of his mounted men are the 5000 who are going with wheeled transport and at q rate that possibly bring them to Mafeking on Monday or Tuesday next.
#
#  Lord Roberts narrative closes with Thursday evening, but he continued his march toward kroonstadt, twenty miles distant, and by this time he must know whether the Boers intend to fight there.
#
#  Mir. Winston Churchill says there were only 20O0 Boers who opposed the British at Zard river. Another estimate is that 6oo0 naers with six guns made rear guard ac- tion. while many other thousands wlth conveys retired without firing shot
#
#  President Steyn and council of the leaders of several thousand Free Staters in the Lady Brand and Ficksburg distrlct determined to submit to the men the ques- tier. of continuing the war or not at great open-air meeting. The fighting men decided to fight on. Steyn, who appears to be Tn active command, began to advance toward the British and came in contact on Thurs d;y with Calnpbels brigade and Brabants s Horse twenty miles northeast of Thaba Gnu. A smart engagement ensued wlth no positive success either side except that the Boer advance was stopped. Gen eral Bundle has placed 10000 infantry along a twenty mile front in such way as to oar Boer advance toward Lord Roberts com munications.
#
#  According to a Pretoria telegram General Butler is moving from Elandslaagte In the direction of Helpmakar.

# %%
import pandas as pd
# It is possible to visualze the frequency of appearance over time

# let's initialize a list of our dates
list_of_dates = []

# let's loop over our article indices
for article_n in dict_of_articles_containing_boer_war_churchill.keys():

  # let's grab the date
  date = dataset_article_level["1900"][article_n]['date']

  # let's add to our list
  list_of_dates.append(date)

# %%
#  now let's plot the frequency by date
df = pd.DataFrame({'date': list_of_dates})
df.groupby('date').size().plot(kind='bar', figsize=(15,9))
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ### IIb: Scan level

# %%
# let's inspect the structure
print(dataset_scan_level)
# Out:
# DatasetDict({
#     1900: Dataset({
#         features: ['raw_data_string'],
#         num_rows: 77496
#     })
# })

# %%
# let's inspect the data for 1900. Note that this data is provided as a string.
# We can easily convert to a JSON

# get the string
raw_data_string = dataset_scan_level["1900"][0]['raw_data_string']

# convert to a dict
article_json = json.loads(raw_data_string)

# inspect which features we have
article_json.keys()
# Out:
# dict_keys(['page_number', 'scan_url', 'scan_ocr', 'scan', 'bboxes', 'edition', 'full articles'])

# %% [markdown]
# Each scan contains several pieces of information:
#
# 1. The page it appears on
# 2. The URL linking to the original page scan
# 3. Meta-information on the scan (scan and scan_ocr)
# 4. A dictionary of the bounding boxes that we identified on the page
# 5. The date of this edition
# 6. A dictionary of full_articles appearing on this page. Here it is
# especially important to note that we include a list of the bounding
# boxes that together form the article

# %%
# Each scan contains several pieces of information, here we are just accessing the
# first article
article_json['full articles'][0]
# Out:
# {'object_ids': [47, 49, 30, 0],
#  'headline': 'BOAT RACES\n\nROWING ASSOCIATION MEETS\n\n\nAND ACTS.\n\nAll Three Clubs Represented-Financ\nAre in Good Condition-Question OF\nTraining Quarters-Club Captains.',
#  'article': "There are to be rowing races next\nSeptember\n\n\nThe Hawaiian Rowing Association\nheld a meeting last night at the resi-\ndence of A. G. NJ Robertson. All three\nclubs were represented. The Healanis\nwere represented by Walter Wall and\nF.. w. Klebahn; the Myrtles by A. G..\nNJ. Robertson, A. A. Wilder. and w.\nw. Harris, and the Leilanis by John\nLane.\n\n\nThe accounts of last year were audit\ned and approved, and show a balance on\nhand of 1858 So.\n\n\n1t was decided that there should be\na regatta held the second Saturday in\nSeptember on the Pearl Harbor course.\n{ two races, senior and Junior, four cared\nboats. There were no restrictions plac-\ned on the kind of boat to be used, and it\nis probable that the Australian boats\nused last year, will be again used this\nyear. though the question of new boats\nmay come up for consideration as n\nclub matter in each club. The usual\ntrophies were decided on, silver cups for\neach race and a banner for the cham\npionship.\n\n\n1t was urged that the Leilanis seek to\n( put themselves on the basis of a COM\n| peting club. At present the club has\n! no clubhouse and it's boats even. are\n! kept now at the Healani clubhouse. The\n| interest the Rowing Association has in\n! this matter is, that as at present con-\n! Stituted, the association is constituted\n/ of the three clubs, only two of which\n/ are active organizations, but the third\n/ has the deciding vote in matters in\n! which under present conditions II can\nnot actively participate in This, It is\n/ thought, is not quite justice tn the other\n/ two.\n\n\nThe question of training quarters at\nPearl Harbor was brought up and dis\n| cussed. The sentiment seemed to pre-\n! vail that this was not strictly mat\n/ ter for the Rowing Association, but was\n! a matter for individual club action.\n| But to prepare the way and bring It\n( before the clubs in a shape that would\npresent ii for discussion and action, w.\n\n\nw Harris was appointed committee\n\n\nof one to confer with the Oahu Railway\nto see If a basis of negotiations could\nbe secured The plan so far proposed,\n\n\nis that the railroad company shall set\n\n\naside a plot of land at the harbor and\n! build suitable cottages upon ii, and rent\n\n\nthat has been much discussed, and it's\n\n\nadvantages are acknowledged, but there\n\n\nis a hesitancy on the part of the clubs\n\n\nto incur the expense and obligation\n\n\nthat would be created by lease of this\n\n\nkind. However ii is q question that\n\n\nwill be brought before the clubs in a\n\n\ntangible shape, and the manifest ad-\n\n\nvantages of such quarters may over\n\n\ncome the objection to expense.\n\n\nThe question of captains has already\n\n\nbeen taken up by the clubs. A. L. c..\n\n\nAtkinson has been chosen captain OF\n\n\nthe Healanis. and will begin very soon\n\n\nto get the boys in training. w. w.\n\n\nHarris is captain of the Myrtles, but\nhas asked the club to accept his resig-\n\n\nnation at the end of this month. He\nfeels that he cannot give the time to the\nmatter that the captain ought to, and\n\n\nthat there is plenty of good material in\nthe club for the position,",
#  'byline': '',
#  'bbox_list': [{'x0': 3707, 'y0': 837, 'x1': 4384, 'y1': 984},
#   {'x0': 3723, 'y0': 1013, 'x1': 4374, 'y1': 1110},
#   {'x0': 3713, 'y0': 1149, 'x1': 4394, 'y1': 1292},
#   {'x0': 3707, 'y0': 1331, 'x1': 4389, 'y1': 3773}],
#  'bbox': [3707, 837, 4394, 3773],
#  'full_article_id': 1,
#  'id': '1_1900-05-08_p1_sn82015415_00237283892_1900050801_0051.json'}

# %%
# note that this dictionary lists the bounding boxes the article is composed
# of, the article text, and the article id. If we want, we can use this article
# id to link articles we found above to their pages. Note that all article text
# that you can explore using the article data, you can also explore using the
# scan data

# %% [markdown]
# ### Let's now go back to the evenstar
#
# We will try to find the page that the article we identified above appeared on

# %%
# let's start with identifying the article id
article_id_of_interest = dict_of_articles_containing_spring_style_infants_shoes[5]
print(article_id_of_interest)
# Out:
# 7_1900-03-23_p6_sn83045462_00280655326_1900032301_0034

# %%
# we will take our article and loop through articles on page to find the
# relevant page

# we want to find articles back later. Let's record the index of the page and
# then the index of the article that we're looking for
page_with_hit = {}

# proceed like before, looping through all scans (we saw above how many there are).
# This should take 3
for scan_n in tq.tqdm(range(77496)):

  # get the string
  raw_data_string = dataset_scan_level["1900"][scan_n]['raw_data_string']

  # convert to a dict
  article_json = json.loads(raw_data_string)

  # now we have to loop through articles
  for article_n in range(len(article_json["full articles"])):

    # let's grab the article
    article_data = article_json['full articles'][article_n]

    # note that the ids have '.json' attached here
    article_id = article_data["id"].split(".")[0]

    # let's see if the id matches
    if article_id == article_id_of_interest:
      page_with_hit[scan_n] = article_n
    else:
      pass
# Out:
# 100%|██████████| 77496/77496 [01:26<00:00, 898.41it/s]

# %%
page_with_hit
# Out:
# {1: 5}

# %% [markdown]
# ## Application: What other articles are printed with our article
#
# Now that we have identified the page we can ask what other articles were
# printed on the page that our article of interest appears on!

# %%
# let's get the page our articles appears on
raw_data_string = dataset_scan_level["1900"][1]['raw_data_string']

# convert to a dict
article_json = json.loads(raw_data_string)

# %%
# let's inspect that we have recovered our article
article_json['full articles'][5]
# Out:
# {'object_ids': [41, 6],
#  'headline': 'Young Folks\nSpring Shoes.',
#  'article': "Our stock of Shoes for young peo-\npie comprises the best and most rep\nutable goods manufactured. All the\nlatest and most improved shapes are\nrepresented, and both service and\nappearance were considered i'll their\nselection. We are also showing the\nLow Shoes for misses and children,\nin welt and turn sole, patent leather.\nvici kid and Russia calf; and the Nici\nKid Spring Heel Shoes with patent\ntips, in extra sizes (21a to 51a). At\ntention is also called to our lines Of\nInfants Cacks and Soft Sole Shoes,\nin black, tans and other colors.\n\n\nThe spring styles are ready.\n\n\nYouths Shoes sizes II to . Pair. 81 so to 50. 80\nBoys Shoes; sizes 21a 5h. Pair S15O to IS 90\nMisses Shoes; sizes II to p Pair .s15O to $500\nChiliren's Shoes; sizes sls to 1Ol9 Pair\n\n\nS1.25 to s.. 90\nInfants Shoes: sizes 6 to s. Pair 81 90 to 81 II\nInfants Cacks; sizes 2 TO g. Pair soc. to 81 %\nMisses OYford5: sizes II to .. Pair. 81 50\nMisses Springfield Oxfords extra sizes, 2H to\noi2. Falr -SZ.oo\nChiiren's O1fords; sizes SA, to 1oR Pair. 81 SO\nInfants oxfords sizes to S. Pair. 81 80\nThird floor",
#  'byline': '',
#  'bbox_list': [{'x0': 2723, 'y0': 3156, 'x1': 3077, 'y1': 3262},
#   {'x0': 2718, 'y0': 3270, 'x1': 3365, 'y1': 4350}],
#  'bbox': [2718, 3156, 3365, 4350],
#  'full_article_id': 7,
#  'id': '7_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'}

# %%
# now we can inspect what else appeared on that page that day!
article_json['full articles']
# Out:
# [{'object_ids': [57, 0],
#   'headline': '',
#   'article': "The District committees should start i'm\nmediately to secure action on certain pend\ning street railway extension bills which\nrepresent the urgent needs of thousands of\nwashingtonians. These bills, specifically,\npropose a westward extension of the Cap\nital Traction line from the State. War and\nNavy building. to furnish transit facilities\nto the people living in that section south of\nPENNSYLVANIA avenue; an eastward extern\nsion of the same line from Sth street and\nPennsylvania avenue southeast to the\nEastern Branch, to cover wide area now\ndevoid of transportation advantages; and\na northeastward extension of the Metro\npolitan line from Columbia road and 18th\nstreet to Park street, to supply the needs\nof a large and rapidly growing suburban\ncommunity living west of 14th street.\n\n\nIrrespective of the wishes or plans of the\nrailroad companies, these improvements are\ndemanded by the people in accordance with\nthe general street railway development of\nthe capital. The chief problem Of the local\nrapid transit situation, that of motive\npower. has been admirably solved. The\nroads are now organized most efficiently\nfor the good of the people and in all re-\nspects as far as it goes the system is well\nnigh perfect. But to make it fully effec-\ntive IT should be made to cover the places\nnow devoid of service. which certain to\ngrow even If they are deprived of these\nfacilities, and of course if given them will\nadvance rapidly.\n\n\nThe street railway improvements should\nbe made to keep pace with the building i'm\nprovements of the city. In order to do this\nprompt action is required on at least two of\nthese bills. particularly that relating to the\nColumbia road extension of the Metropoli-\ntan. That project involves the widening of\nthe road to accommodate the railroad line.\nThere is no time to be lost in starting this\nprocess, for improvements have already\nbeen begun there. involving the erection of\na block of houses which, under the terms\nof the contemplated extension. will have\nto be demolished. 1t is only reasonable to\nexpect that Congress viii take cognizance\nof this fact and make haste to start the\nrailroad work before the cost shall have\nbeen largely increased through these build\ning operations and others certain to follow.\n1t Is unfair to investors who are anxious to\nstart the construction of houses along this\nline to compel them to wait indefinitely be-\nfore they can proceed with confidence as TO\nthe future.\n\n\nYet this is what IS being done. The de-\nlays in the houses in handling these bills\nare having the effect of strangling the i'm\nprovement of this large and promising sec\nton while depriving the people already To-\nGated there of rapid transit facilities\nEvery consideration of good government\ndemands immediate action. the interests of\nthe people alone calling for the enactment\nof this legislation and the furnishing to the\nnow neglected sections of the railroad lines\nwhich might so readily be extended to\nthem",
#   'byline': '',
#   'bbox_list': [{'x0': 754, 'y0': 1158, 'x1': 1347, 'y1': 1199},
#    {'x0': 724, 'y0': 1207, 'x1': 1372, 'y1': 3455}],
#   'bbox': [724, 1158, 1372, 3455],
#   'full_article_id': 1,
#   'id': '1_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [58, 1],
#   'headline': '',
#   'article': 'When the Porto Rican tariff bill was put\nupon it\'s passage its advocates declared that\nthe people would indorse it so soon as they\nshould come to understand II. That was\nweeks ago Since then public discussion\nhas been busy with the topic to the exclu-\nsion of nearly every other The leading\nnewspapers have yielded unlimited space\nto it Has there been a single conversion of\nnote to the cause? Not a newspaper has\ngone over. Not a public man of any conse-\nquence has gone over The boot is on the\nother leg. The opposition to the bill has in\ncreased in strength. The press, speaking\nfor the people. assail the measure more Wig\norously today than at any other time. SEN\nat0rs whose course was not clearly de-\nfined at the outset are out in the open now\nurging the defeat of the bill. The lowe\nhouse of representatives assumes to under\nstand it. and pronounces unanimously\nagainst it. What is the information about\nthe bill which is to convert the multitude\nto its support? And who possesses it, and\nwhy does he not bring it forward?\n\n\nII conversions were possible they would\nsome time since have begun. They are not\npossible. The bill has no standing upon\nIts merits. 1t is not now being urged upon\nit\'s merits. 1t is in the hands of men who\noriginally were for free trade with Porto\nRico. Some of them, too, there is good rea-\nson to believe. regret their present attitude.\nThey are upholding the measure through a\nmistaken sense of party loyalty They are\nfighting not for a redemption of the i\'m\npiled pledges Of the government to friend\nly and deserving and helpless people in les-\nperate need of succOr and Justice. but to\nsave the republican leaders of the House\nfrom the consequences of their own folly.\nThey are not called upon to do this thing.\nLet those leaders square themselves with\ntheir constituents and the country. To save\nthe party is more than to save a laundering\nleadership from deserved modification.\n\n\n1t will be a most strange fate if the party\nof protection shall be forced to go to de-\nfeat in behalf OF duty laid largely in\nthe interest of the sugar growers of Louisi-\nana. and by the aid of their representatives\nin Congress. when the votes of that state\nir the electoral college are Invariably cast\ni\'ll favor of free trade candidates for the\npresidency. Louisiana is for Mr.. Bryan for\nPresident. and if Mr.. Bryan is elected his\ntriumph will be the triumph of the Tree\ntrade party. A new crusade against protec-\ntion will Immediately be inaugurated. Is\n1t worth while TO risk so much for so little"\nIs the Oxnard leadership one to be well\ncoined at this time?',
#   'byline': '',
#   'bbox_list': [{'x0': 178, 'y0': 795, 'x1': 591, 'y1': 831},
#    {'x0': 63, 'y0': 835, 'x1': 710, 'y1': 2804}],
#   'bbox': [63, 795, 710, 2804],
#   'full_article_id': 2,
#   'id': '2_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [2],
#   'headline': '',
#   'article': "formation of a sort which Is useful in the\naverage career. In the seventh grade the\ngeographical text book is far beyond the\nmental development of those who are re-\nquired to study it.\n\n\nThe lesson taught by this report and by\nthe experiences so liberally debated here\nduring the past two or three months is\neasily to be understood. In an undoubt-\nedly conscientious endeavor to make our\nschools rank high in the opinions of 'edu-\nGators the authorities have wandered far\ninto the realm of theory, leaving behind\nthem as ancient and unworthy many of the\nprinciples which must underlie education If\nit is to be of any practical use. The effort\nhas been to generalize and incidentalize so\nthat the pupil would acquire knowledge\nwithout being aware of the requirement.\nand this in spite of the fact that there is\nno royal road to learning The man whose\nprinciples are vague and ill-defined never\nsucceeds in this world. The man whose\neducation is devoid of drill and rules and\nsteady application to specific and directly\nuseful studies is seriously handicapped In\nthe struggle for existence. The school au-\nthoritieS may with credit to themselves\nand profit to the community spend consid-\ncradle time and thought on revision of\ntheir impractically administered course of\nstudy",
#   'byline': '',
#   'bbox_list': [{'x0': 729, 'y0': 129, 'x1': 1372, 'y1': 1134}],
#   'bbox': [729, 129, 1372, 1134],
#   'full_article_id': 3,
#   'id': '3_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [84, 3],
#   'headline': 'MARYLAND at Kansas CITY.',
#   'article': "The esteemed Baltimore Herald, in this\nparagraph. shows a natural interest in\ndistinguished Maryland statesman:\n\n\nTHE Washington Star says: Mr.. German\nwill be a delegate to the Kansas City con-\nvention.' By what authority does our\nprophetic cotemporary speak?\n\n\nBY this authority:\n\n\n% Mr.. German is gold democrat. He\nexpects to support Mr.. Bryan on any plat\nform the Kansas City convention may\nadopt. But he would be glad to see one of\nq conservative character on the money\nquestion written. He thinks it essential to\ndemocratic success at the polls, indeed,\nthat in some way the Chicago deliverance\non that question be modified He is an ex-\npert platform builder, and eastern demo-\nGratis who agree with him about this matter\nare looking to him for valuable assistance\nin the effort to smooth the way for their re-\nturn to the party fold\n\n\n-, Mr.. German is easily the leader of the\nMaryland democracy. His word is law\nThe organization obeys him gladly. He\ndominated the situation last year complete\nIy. Both ticket and platform were his\nWhy should he not dominate this year $\nsituation also? OF course he will. The deb\negates to Kansas City will be men alto\ngether acceptable to him. and will under\nstand and follow his wishes. Why should\nhe not go at their head? Who does not\nknow that the delegation without Mr. Cor\nman would lose materially in both interest\nand influence?\n\n\n10 Were Mr.. German TO fail TO attend\nThe national convention he would be\ncharged with Indifference; and there is no\nreason 10 believe that he is Indifferent.\nWere he 10 attend merely as a spectator\nhe would lack opportunities of enjoyment.\nWhen A great drama is on the boards. a\ngreat actor prefers to be in the cast. And\nMIR. German is undoubtedly Il great actor\nin the political drama. AS the head of\nthe Maryland delegation. with definite\nobject in view and marked skill in the fur\ntherance of his ends, Mr.. German will be\none of The most conspicuous men in the\nconvention. Those who agree with him will\nimplicitly follow him, while those who diff\nfer with MIN will treat him with due con-\nsideration II is indeed an unusual op-\nportunity for man of MIR. Gorman's tai\nents and temperament.\n\n\nAS the Herald understands. The Star\nspoke confidently, but with confidence born\n| of the considerations mentioned. Is there\nany reason to believe that IL has spoken\n\\ too confidently?",
#   'byline': '',
#   'bbox_list': [{'x0': 824, 'y0': 3474, 'x1': 1277, 'y1': 3515},
#    {'x0': 729, 'y0': 3529, 'x1': 1377, 'y1': 5434}],
#   'bbox': [729, 3474, 1377, 5434],
#   'full_article_id': 4,
#   'id': '4_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [5],
#   'headline': '',
#   'article': "tivity of the community. This principle,\nfaithfully maintained. leads to prosperity.\nIts violation leads directly to business stag\nnation, depression and ultimately. IL un-\nchecked. to panic.\n\n\nIn the case of the proposed tax revision\nbill relating to the District the reverse prin-\nciple seems TO have been established as a\nfoundation. The chief aim has apparently\nbeen to tax every visible form of industry.\nenterprise or occupation, to put penalty\nupon all forms of human labor. whatever\nthe ability to pay. There are certain occu-\npations which, from their character. require\nlicensing, in order to permit police regula-\nton. In such case a tax is desirable, even\nnecessary. But these cases are few COM\npared with the manifold business interests\nof citizens, merchants, workers and miscel-\nlaneous tradesmen whose energies reflect\ncredit upon the community. and should re-\nmain, as far the public needs will per-\nnit absolutely unhampered by special tax\nalton.\n\n\nA city which taxes indiscriminately, which\nexacts fee from enterprise, soon acquires\nan undesirable reputation among the work\ners. Washington is just now seeking to at\ntract light manufacturing, to draw hither\nvarious forms of labor-employing enter\nprises which will comport with the dignity\nof the capital and at the same time swell\nthe self-supporting population. 1t is excep-\ntionally situated to attract workers and in\nvestors as regards the financial burdens\nplaced upon the people. The aid furnished\nby the federal government in maintaining\nthe municipal machinery, the extensive i'm\nprovements made possible by this division\nof the cost, the growing prestige of the\ncity as a desirable place of residence and\nwell-governed community, all tend to\nspread its fame and invite home-makers,\nartisans and capitalists.\n\n\nThe proposed tax law is calculated to\nstem this tide and to change the citys fame\ninto disrepute. 1t contains enough harmful\npropositions to affect all the natural local\nadvantages and to discourage even the en-\nterprses already located here. 1t is in the\ninterests of the Washington not only of to-\nday, but the Washington of the future, that\nthis measure be pigeon-holed or else revised\nto meet the judgment of the community,\nwhich is today decidedly adverse to it's con-\nsideration.",
#   'byline': '',
#   'bbox_list': [{'x0': 1386, 'y0': 124, 'x1': 2038, 'y1': 1899}],
#   'bbox': [1386, 124, 2038, 1899],
#   'full_article_id': 6,
#   'id': '6_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [41, 6],
#   'headline': 'Young Folks\nSpring Shoes.',
#   'article': "Our stock of Shoes for young peo-\npie comprises the best and most rep\nutable goods manufactured. All the\nlatest and most improved shapes are\nrepresented, and both service and\nappearance were considered i'll their\nselection. We are also showing the\nLow Shoes for misses and children,\nin welt and turn sole, patent leather.\nvici kid and Russia calf; and the Nici\nKid Spring Heel Shoes with patent\ntips, in extra sizes (21a to 51a). At\ntention is also called to our lines Of\nInfants Cacks and Soft Sole Shoes,\nin black, tans and other colors.\n\n\nThe spring styles are ready.\n\n\nYouths Shoes sizes II to . Pair. 81 so to 50. 80\nBoys Shoes; sizes 21a 5h. Pair S15O to IS 90\nMisses Shoes; sizes II to p Pair .s15O to $500\nChiliren's Shoes; sizes sls to 1Ol9 Pair\n\n\nS1.25 to s.. 90\nInfants Shoes: sizes 6 to s. Pair 81 90 to 81 II\nInfants Cacks; sizes 2 TO g. Pair soc. to 81 %\nMisses OYford5: sizes II to .. Pair. 81 50\nMisses Springfield Oxfords extra sizes, 2H to\noi2. Falr -SZ.oo\nChiiren's O1fords; sizes SA, to 1oR Pair. 81 SO\nInfants oxfords sizes to S. Pair. 81 80\nThird floor",
#   'byline': '',
#   'bbox_list': [{'x0': 2723, 'y0': 3156, 'x1': 3077, 'y1': 3262},
#    {'x0': 2718, 'y0': 3270, 'x1': 3365, 'y1': 4350}],
#   'bbox': [2718, 3156, 3365, 4350],
#   'full_article_id': 7,
#   'id': '7_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [60, 10],
#   'headline': 'Muslin\n\n\nUndergo armemts.',
#   'article': "The following lots OF Women's\nCndergarments are the fullest values\npossible to offer at the prices. The\nmaterials alone would cost YOU as\nmuch as we ask for the finished gar\nment:\n\n\nWomen's Muslin Drawers with h.mstitch.d ruff\ne.\nWomen Muslin Gowns. high neck plain\ntucked yoke or trimmed with embroidery Pr .J.lc\n\n\nWomenS Cambria and Muslin Gowns. ponte,\nyoke With two rows of insertion and tucks; collar\nand cuffs edged with embroidery Each. Toe\n\n\nWomen Cambria and Muslin Short Skirts trim\nmed with rafie of embroidery and cluster Of tucks\nEach. ............ ..........,....- -u..\n\n\nWoinens Walking Skirts. Spanish iOunce. with\ncluster of tucks and yoke band Each ....... Soc\n\n\nWomen Blouse Corset Covers. cambric and ma in\nsock, four styles. round and square neck, embrOi-\nerys and lace trimmed. Each. .............50 soc\nSecond floor.",
#   'byline': '',
#   'bbox_list': [{'x0': 3394, 'y0': 4493, 'x1': 3793, 'y1': 4594},
#    {'x0': 3389, 'y0': 4603, 'x1': 4036, 'y1': 5195}],
#   'bbox': [3389, 4493, 4036, 5195],
#   'full_article_id': 11,
#   'id': '11_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [65, 13],
#   'headline': 'Revise the Course of study.',
#   'article': 'In tn, news columns Of this issue of The\nStar will be found the major portion of an\nofficial report in which is set forth the\ncourse of study in the graded public schools\nof the District OF Columbia The course of\nstudy has been much discussed of late.\nThose who believe in it. or think they do,\narr vaguely enthusiastic even when they\nare not making converts. Those who are\ncritical have failed at times to be satisfac-\ntortly strong because the so-called course\nwas intangible and could noe easily be put\nin evidence. In the report referred to there\nseem to be facts sufficient for Indictment\npurposes Careful and equitable analysis\nJoined to practical knowledge of results\ncompels the conclusion that the so-call.d\nsystem is unsystematic. is overcrowded\nwith high-sounding but non-essential sub\njrcrs is illogical as to its relationship with\nreal life and throughout its entire course\nsacrifices desirable depth TO comparatively\nValLeiess breadth\n\n\nBY those who advocate the conditions\nwhich have resulted in senatorial inquiry\nit is claimed that there has been great i\'m\nprov .ment in the teaching and requirement\nOf language. and to some extert that i\'m\nprovement will be conceded. but in view of\nthe supervising principals report it is time\n~ HllElllT-I tllc 44llpLpN tliltllI mas Dttn\nin ratio to the emphasis given the subject;\nare not the children being forced through\nbewild-ring rnazes Of technical Language\nwhen they should devuce a considerable\nproportion of the time thus occupied to\nmore material inforn1a tiun Of the sort cal\nculased to assist them when they arr COM\nr-Iled To earn their daily bread?\n\n\nThroughout all the grades the tendency\nis toward mi~ccnreived idealism. To com\npei TN average sixth-Srade child to study\nLongfrlIuW\'- \'-Evanseline\'\' is little less\nti.ar folly. the youthful mind is not equal\nto The task Says the report:\n\n\nMany II the words needed special prep\nflr7tlHu before the first reading was at\ntempted As with all other reading in the\nrs\'uFS\'.. the children Were taught to pre- pare\ntheir work with the dictionary and atlas for\nconstant reference and they were as con-\nStaHtly held responsible for correct spelling.\npr"nunS!sgti"H. punctuation and the trans\nformation a< these elements appeared in all\ntheir speech and writing\n\n\nBut If speIling-drin is tabooed-as il has\nh-~n-hgw Is the dictionary to be useful?\nIf 4 grammar Textbook is shelyed-as il\nhas becn-hOw can there be accurate pre-\nnunciati"n. punctuation or transformation? :?\nII The written work-the compositions-of\nIN" pupils is To be uncorrected and thrown\ninto the waste-basket how can the repeti-\nti0H Of errors be avoided?\n\n\nThe study Of the parts Of speech was\ncontinued. says the report being taken\nup iii a miscellaneous way as thev were en-\ncountered- That is disorderly lacks thor\noughness and supports the critical couten-\ntiOn that the teaching is indirect and m\nmindful Of sequence\n\n\nArithmeticaI work starts out very sbow-\nlily IN the hrst grade. but IT speedily he\ncomes involved. diffuse and urarfthuleticaI\nThe effort to cultivate sixteen-year-oId rea-\nsoning powers in ten-year-old children by\nmystic discussion of \'.relativities of perime-\ntiers and areas" has supplanted the siusple\nana mechanical processes which business\nexperience declares are essential in busi-\nness life An interesting scrap of testf-\nmOny is the Official statement that The\nreview in the seventh grade (arithmetic) was\nfinished by the Ist of November. and tbe\nsubject was completed in this grade" That\nsettles all quibbling as to the official inten-\ntion TO have no arithmetic in the eighth\ngrade. and leads to the related fact that al\na meeting of seventh grade teachers. held\nlast year. notice was given that the ef-\nfort would be made TO finish arithmetic in\nthe sixth grade in the year 1890.\n\n\nSubject to the same criticism-lack Of sys.\ntenn and carelessness as to the t ...
#   'byline': '',
#   'bbox_list': [{'x0': 148, 'y0': 3101, 'x1': 626, 'y1': 3132},
#    {'x0': 68, 'y0': 3136, 'x1': 720, 'y1': 6284}],
#   'bbox': [68, 3101, 720, 6284],
#   'full_article_id': 14,
#   'id': '14_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [75, 15],
#   'headline': 'As PROPOSED to Porto Rico.',
#   'article': "They are playing Yankee Doodle\nWhere they once played Spanish airs.\nSo pause awhile to listen\n\n\nAnd forget commercial cares.\nYou know you liked the music\n\n\nFor you welcomed it with glee.\nBut you've got to pay the fiddler\nAnd he wants a liberal fee.\nYou have heard of prima donnas\nAnd pianists who will quote\nSmall fortunes as the ransom\n\n\nEre they liberate note.\nThe sugar trusts an artist\n\n\nAS the world will all agree.\nYou've got to pay the fiddler\n\n\nAnd he wants a liberal fee.",
#   'byline': '',
#   'bbox_list': [{'x0': 1485, 'y0': 3892, 'x1': 1938, 'y1': 3923},
#    {'x0': 1410, 'y0': 3932, 'x1': 1998, 'y1': 4460}],
#   'bbox': [1410, 3892, 1998, 4460],
#   'full_article_id': 16,
#   'id': '16_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [76, 19],
#   'headline': 'Corset\n\n\nDepa arenemt.',
#   'article': "A most carefully selected stock of\nCorsets, foreign and domestic, is here\nin satisfactory variety. A generous\nsprinkling OF Paris novelties, includ-\ning many beautiful specimens for\nevening wear.\n\n\nC. B. Corsets. extra long. medium and short.\n1alr .Si.oo\n\n\nZ. d. CorSets. French cout extra long and\nshort. Fair. ST. 10\n'Parame Corsets, batiste. straight front. low bust,\nlong hips Pair. $500\n\n\nEmpire Co.sets, hatiste, white, pink, blue and\nlavender. falr. .Sb-oo\n\n\nLily Of France Corsets, French coutil, straight\nfront. Pair. ar...................... sc. 90\nRibbon Girdles. in dainty shades of pink. blue\nand lavender. Pair. $50\nSecond floor.",
#   'byline': '',
#   'bbox_list': [{'x0': 2723, 'y0': 4369, 'x1': 3047, 'y1': 4470},
#    {'x0': 2723, 'y0': 4478, 'x1': 3375, 'y1': 5101}],
#   'bbox': [2723, 4369, 3375, 5101],
#   'full_article_id': 20,
#   'id': '20_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [61, 20],
#   'headline': 'No Tax-Ridden Washington.',
#   'article': 'The general tendency Of municipal taxa\nton, as. indeed every other form Of se-,\ncuring from the people the necessary money\nfor the maintenance of government. Is to\navoid making the raising of revenue an OBJ\nstructive burden upon the business enter\nprise Of the people. The CREST bulk Of the\nincome is derived from real estate. When\never it becomes necessary to go beyond the\nland and its immediate appurtenanceS for\nrevenue wise Legislators try to prevent the\nprocess from affecting the commercial ac-',
#   'byline': '',
#   'bbox_list': [{'x0': 814, 'y0': 5850, 'x1': 1312, 'y1': 5886},
#    {'x0': 749, 'y0': 5895, 'x1': 1392, 'y1': 6264}],
#   'bbox': [749, 5850, 1392, 6264],
#   'full_article_id': 21,
#   'id': '21_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [62, 92, 22],
#   'headline': '\n\n',
#   'article': 'JOuTIuI.\n\n\nThe question is not one of dollars and\ncents: it is one of morals and of brotherly\ncharity. We saw the lOng-suffering Span\nish colony bleeding and helpless by the way\nside. We turned Samaritan with only the\nkindliest and most generous objects in\nview. Shall We become at this late day like\nthe Levite Of the parable or like the impe-\nrial governments of Europe that used to\nthink that colonies existed only for what\nmight be got out of them?',
#   'byline': '',
#   'bbox_list': [{'x0': 1475, 'y0': 4478, 'x1': 1953, 'y1': 4519},
#    {'x0': 1400, 'y0': 4528, 'x1': 1839, 'y1': 4559},
#    {'x0': 1395, 'y0': 4543, 'x1': 2038, 'y1': 4852}],
#   'bbox': [1395, 4478, 2038, 4852],
#   'full_article_id': 23,
#   'id': '23_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [52, 24],
#   'headline': 'Antiseptic Sanitary\nDiaDer Cloth',
#   'article': 'Is: chemically pure and absorbent\n\n\nMade of especially selected cotton,\nbfeached with the purest chemicals.\nfree from starch and foreign matter,\nsterilized by heat, sealed from the\nair, ready for use. Ten yards in a',
#   'byline': '',
#   'bbox_list': [{'x0': 2723, 'y0': 5115, 'x1': 3211, 'y1': 5205},
#    {'x0': 2728, 'y0': 5214, 'x1': 3375, 'y1': 5454}],
#   'bbox': [2723, 5115, 3375, 5454],
#   'full_article_id': 25,
#   'id': '25_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [63, 25],
#   'headline': 'Boys\nFurnishings.',
#   'article': 'his stock is located Immediately\nat the left of entrance to Mems De\npartment, and contains everything in\nfurnishings, in the correct proper\ntons and styles for boys.\n\n\nUmbrellas in 22 and 24-inch sizes\nwith handles suitable for boys and\ngirls.',
#   'byline': '',
#   'bbox_list': [{'x0': 3389, 'y0': 3161, 'x1': 3708, 'y1': 3252},
#    {'x0': 3384, 'y0': 3266, 'x1': 4036, 'y1': 3570}],
#   'bbox': [3384, 3161, 4036, 3570],
#   'full_article_id': 26,
#   'id': '26_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [73, 101, 26],
#   'headline': '\n\nFrom the Philadelphia Press.',
#   'article': "1t is exceedingly unfortunate that the\nLoud bill, providing for certain very i'm\nportant and desirable reforms in postage on\nsecond-class matter, was defeated in the\nHouse yesterday. Misrepresentation and\nmisunderstanding have been fatal to this\nproposed reform before, but it had been\nurged with such intelligent purpose this\ntime that there was hope of its adoption.\nApparently it will have to wait some time\nyet, at the further cost of S20,O00.000 a year\nto the people.",
#   'byline': '',
#   'bbox_list': [{'x0': 1440, 'y0': 4871, 'x1': 1958, 'y1': 4912},
#    {'x0': 1405, 'y0': 4916, 'x1': 1943, 'y1': 4952},
#    {'x0': 1400, 'y0': 4941, 'x1': 2043, 'y1': 5265}],
#   'bbox': [1400, 4871, 2043, 5265],
#   'full_article_id': 27,
#   'id': '27_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [77, 27],
#   'headline': 'A Sufferers Confession.',
#   'article': "l envy not the nabob's gold,\nl scorn the monarch's might;\nl covet not the right to hold\nA place in Fashions sight.\nYet Satan bids me join his clan.\nOne pitfall, and l slip.\nl envy heartily the man\n\n\nWho hasn't got the grip.",
#   'byline': '',
#   'bbox_list': [{'x0': 1500, 'y0': 3275, 'x1': 1913, 'y1': 3306},
#    {'x0': 1475, 'y0': 3315, 'x1': 1988, 'y1': 3575}],
#   'bbox': [1475, 3275, 1988, 3575],
#   'full_article_id': 28,
#   'id': '28_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [69, 29],
#   'headline': '',
#   'article': 'do You remember when Porto Rico well\ncoined the American soldiers with brass\nbands and bouquets?"\n\n\nYes" answered Senator Sorghum. Il\nresented it at the time. l thought then\nthat those people ought to be saving up the\nmoney they were spending for music and\nfloral tributes so as to pay taxes"',
#   'byline': '',
#   'bbox_list': [{'x0': 1589, 'y0': 3589, 'x1': 1839, 'y1': 3614},
#    {'x0': 1391, 'y0': 3623, 'x1': 2033, 'y1': 3883}],
#   'bbox': [1391, 3589, 2033, 3883],
#   'full_article_id': 30,
#   'id': '30_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [71, 30],
#   'headline': 'Naturally Interested.',
#   'article': "'Is it true that you Filpinos are making\nsecret visits to Manila?'\n\n\nWell answered the native. we've got\nto get into Manila once in a while as to\nget the news from the sympathiZers in\nAmerica and find out how the war is get\nting on",
#   'byline': '',
#   'bbox_list': [{'x0': 1530, 'y0': 2997, 'x1': 1894, 'y1': 3028},
#    {'x0': 1395, 'y0': 3037, 'x1': 2043, 'y1': 3257}],
#   'bbox': [1395, 2997, 2043, 3257],
#   'full_article_id': 31,
#   'id': '31_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [56, 100, 31],
#   'headline': '\n\n',
#   'article': 'No said the practical politician "we\ndon\'t want him figuring In the campaign"\n\n\nBut he is exceedingly well informed\n\n\nIl doubt it. He has put in all his time\nstudying the tariff and finance and the\nUnited States Constitution. He doesn t\nknow anything about politics.',
#   'byline': '',
#   'bbox_list': [{'x0': 1540, 'y0': 2465, 'x1': 1884, 'y1': 2506},
#    {'x0': 1530, 'y0': 2520, 'x1': 1889, 'y1': 2556},
#    {'x0': 1395, 'y0': 2565, 'x1': 2033, 'y1': 2794}],
#   'bbox': [1395, 2465, 2033, 2794],
#   'full_article_id': 32,
#   'id': '32_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [81, 47, 32],
#   'headline': "SOC. and 75c. each.\n\nSpecials i'm\nWomem's Hosiery.",
#   'article': "We are pleased to announce dupli-\ncate orders of the following lots oi\nHosiery. which represent the best in\ntrinsic values obtainable for the\nprices:\n\n\nso dozen Women's Fast Black LiSlc Hose with\ndouble soes and h'gh-spliced heels extra fine and\nelastic.\n\n\n2Ic., 5 pairs for $I.oo.",
#   'byline': '',
#   'bbox_list': [{'x0': 3533, 'y0': 3574, 'x1': 3887, 'y1': 3610},
#    {'x0': 3389, 'y0': 3937, 'x1': 3837, 'y1': 4027},
#    {'x0': 3389, 'y0': 4036, 'x1': 4031, 'y1': 4340}],
#   'bbox': [3389, 3574, 4031, 4340],
#   'full_article_id': 33,
#   'id': '33_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [67, 95, 33],
#   'headline': "Porto RicO's Plight.\n\nFrom the Chicago Journal.",
#   'article': '\n\n\nThe responsibility for the delay and for\nall the distress delay has caused is on the\nheads of those that have wished to do less\nthan their duty. 1t will continue to be on\ntheir heads. Senators and representatives\nthat insist on doing what is right will in\ncur no blame in the eyes of their eonstitu-\nents. The people know the merits OF the\ncase and will hold those responsible who\nought to have yielded and would not.',
#   'byline': '',
#   'bbox_list': [{'x0': 1540, 'y0': 5289, 'x1': 1909, 'y1': 5330},
#    {'x0': 1405, 'y0': 5329, 'x1': 1918, 'y1': 5359},
#    {'x0': 1405, 'y0': 5353, 'x1': 2048, 'y1': 5633}],
#   'bbox': [1405, 5289, 2048, 5633],
#   'full_article_id': 34,
#   'id': '34_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [68, 96, 35],
#   'headline': '\n\nFrom the Chicago News.',
#   'article': 'When the tobacco and sugar interests ask\nthe people of the United States to tax starv-\ning people for their benefit it is time to\ndraw the line II 1t is not drawn by Com\ngress it will be drawn by the people at\ntheir first opportunity This fact seems at\nlast to have been grasped at Washington.',
#   'byline': '',
#   'bbox_list': [{'x0': 1535, 'y0': 5652, 'x1': 1913, 'y1': 5692},
#    {'x0': 1410, 'y0': 5691, 'x1': 1904, 'y1': 5722},
#    {'x0': 1400, 'y0': 5716, 'x1': 2043, 'y1': 5911}],
#   'bbox': [1400, 5652, 2043, 5911],
#   'full_article_id': 36,
#   'id': '36_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [90, 36],
#   'headline': 'Mems\n\n\nDepartment.',
#   'article': 'Complete lines OF Spring and Sum\nmer Shirts, Pajamas, etc, including\nlatest novelties and colorings in\nFrench Percales, Scotch Madras and\nCheviots; Underwear in medium\nweight wool and balbriggan; Spring\nNeekwear, including the popular\nBarathea weave; Gloves in the cor\nrect shades for spring; all the new\nstyles in Collars and Hosiery; also\nchoice assortments of Bicycle Hose,\nSteamer Rugs and Turkish Toweling\nBath Robes.\n\n\nGood wales in low-priced goods',
#   'byline': '',
#   'bbox_list': [{'x0': 3384, 'y0': 2192, 'x1': 3718, 'y1': 2292},
#    {'x0': 3389, 'y0': 2301, 'x1': 4036, 'y1': 2859}],
#   'bbox': [3384, 2192, 4036, 2859],
#   'full_article_id': 37,
#   'id': '37_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [45, 37],
#   'headline': 'Saturdays =\nPure Food List.',
#   'article': "Nantieoke tomatoes, dozen cans. ............ a0r.\nindependence Tomatoes. dozen cans 81 90\nShrivers Silver Label Peas. dozen cans. 81. 10\nioes centennial Peas. dozen cans 81 20\nEureka Extra Sffted Peas. dozen cans. 81 so\noxford Baked Beans, dozen cans. s......-..... 81 IS\ncalifornia Pears, can. 20c.\nCalifornia Peaches, can. zoe.\nDefence Lima Beans. dozen cans............ s1.1O\naiothers Silver Thread Gelatine package. &c.\nSream Codhsh. package OBSERVATION-DISCLOSURES &c.\n\n\nEiaecus Bros. Catsup. bottle. ....-.....-.... 2ie.\nOYSTER bay Asparagus, can ...-......-.... 19c.\nYoung America Corn. can. ...--..-........ &c.\nWebb's Cream Sugar Corn. dozen cans. 81 IS\nimported Macarcni and Spaghetti. 1oc.\n\n\nW1lbur's Cocoa E-lb can. --......-...-.... DC.\nAlden q Nlcboisons Jams: assorted. can. 1or.\nAInour IS key Sotp. lo cakes for. ......-.... &c.\nSehaith Star soap cake. :....-...-...... Sc.\nh1rkman,s BoraG soap cake 4lsc.\nnrocter q dmDies oietne soap, cake. 4lsc.\nW. q L. Laundry soap bar NEUTRALITY-SUSPICIOUS.. Zoe.\nSiFeas soap, CAKES foT -s...-.-.......... 2.c.\nsana ltaus soap, cakes for. r................ &c.",
#   'byline': '',
#   'bbox_list': [{'x0': 3389, 'y0': 5209, 'x1': 3773, 'y1': 5300},
#    {'x0': 3394, 'y0': 5309, 'x1': 4041, 'y1': 5871}],
#   'bbox': [3389, 5209, 4041, 5871],
#   'full_article_id': 38,
#   'id': '38_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [38],
#   'headline': '',
#   'article': "The kaiser's great interest in Chinese af-\nfairs will strike the Beers as showing a\ntendency to get a long way from the sa-\nlIent point of the International situation",
#   'byline': '',
#   'bbox_list': [{'x0': 744, 'y0': 5453, 'x1': 1382, 'y1': 5588}],
#   'bbox': [744, 5453, 1382, 5588],
#   'full_article_id': 39,
#   'id': '39_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [39],
#   'headline': '',
#   'article': '1t is to be hoped that this lull in Ken\nlucky IS something more than a suspension\nof proceedings to give the mountaineers\ntime to clean up their Winchesters.',
#   'byline': '',
#   'bbox_list': [{'x0': 1386, 'y0': 1918, 'x1': 2038, 'y1': 2059}],
#   'bbox': [1386, 1918, 2038, 2059],
#   'full_article_id': 40,
#   'id': '40_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [40],
#   'headline': '',
#   'article': 'Porto Rico will have the sympathy of\nnumber of American statesmen who at\ntribute most of their troubles to some un-\nexpected turn In the tariff question.',
#   'byline': '',
#   'bbox_list': [{'x0': 73, 'y0': 2823, 'x1': 710, 'y1': 2958}],
#   'bbox': [73, 2823, 710, 2958],
#   'full_article_id': 41,
#   'id': '41_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [42],
#   'headline': '',
#   'article': 'There is much regret that Mr. Einstein\nand his athletic assistants cannot be effect\nlively turned loose on the grip germs.',
#   'byline': '',
#   'bbox_list': [{'x0': 739, 'y0': 5612, 'x1': 1387, 'y1': 5712}],
#   'bbox': [739, 5612, 1387, 5712],
#   'full_article_id': 43,
#   'id': '43_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [64, 43],
#   'headline': '',
#   'article': "The man who doesn't change his mind\nSo says the cynic strange\nIs one, you'll usually find\n\n\nWho has no mind to change.",
#   'byline': '',
#   'bbox_list': [{'x0': 1629, 'y0': 2808, 'x1': 1809, 'y1': 2834},
#    {'x0': 1410, 'y0': 2838, 'x1': 2023, 'y1': 2973}],
#   'bbox': [1410, 2808, 2023, 2973],
#   'full_article_id': 44,
#   'id': '44_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [70, 44],
#   'headline': 'The Reaction.',
#   'article': 'Frem the Baltimore American\n\n\n1t is intimated that the Topeka CAPITAL is\ngoing back TO the What Would Ananias\nDor" platform.',
#   'byline': '',
#   'bbox_list': [{'x0': 1604, 'y0': 5935, 'x1': 1854, 'y1': 5966},
#    {'x0': 1405, 'y0': 5975, 'x1': 2048, 'y1': 6085}],
#   'bbox': [1405, 5935, 2048, 6085],
#   'full_article_id': 45,
#   'id': '45_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [46],
#   'headline': '',
#   'article': '1t is a lucky thing for some Of the current\nplays that they do not have to go through\nthe mails in order to reach the public.',
#   'byline': '',
#   'bbox_list': [{'x0': 1391, 'y0': 2217, 'x1': 2038, 'y1': 2322}],
#   'bbox': [1391, 2217, 2038, 2322],
#   'full_article_id': 47,
#   'id': '47_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [48],
#   'headline': '',
#   'article': 'Agoncillo Is telling the Parisans Of great\nFilipino victories. OF course, Agoncillo is\nobliged to do something for his money.',
#   'byline': '',
#   'bbox_list': [{'x0': 1386, 'y0': 2082, 'x1': 2033, 'y1': 2193}],
#   'bbox': [1386, 2082, 2033, 2193],
#   'full_article_id': 49,
#   'id': '49_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [49],
#   'headline': '',
#   'article': 'Switzerland is exceedingly polite to the\nBoer republic, but is not making any bids\nfor trouble on its account.',
#   'byline': '',
#   'bbox_list': [{'x0': 1391, 'y0': 2346, 'x1': 2038, 'y1': 2446}],
#   'bbox': [1391, 2346, 2038, 2446],
#   'full_article_id': 50,
#   'id': '50_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [50],
#   'headline': '',
#   'article': 'The English in South Africa have about\ndecided 70 permanently abandon the regret\n10 report formula.',
#   'byline': '',
#   'bbox_list': [{'x0': 68, 'y0': 2977, 'x1': 715, 'y1': 3078}],
#   'bbox': [68, 2977, 715, 3078],
#   'full_article_id': 51,
#   'id': '51_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [53, 51],
#   'headline': 'All on One Side,',
#   'article': 'From the Chicago Record.\n\n\nThere may be two sides to the question of\nimposing tariff on Porto Rico, but the\npeople are all on one side.',
#   'byline': '',
#   'bbox_list': [{'x0': 1589, 'y0': 6109, 'x1': 1874, 'y1': 6140},
#    {'x0': 1410, 'y0': 6149, 'x1': 2053, 'y1': 6264}],
#   'bbox': [1410, 6109, 2053, 6264],
#   'full_article_id': 52,
#   'id': '52_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [93, 54],
#   'headline': '2Ic., s pairs for ST 90.',
#   'article': "30 dozen Womeu's Fine Black LisIe Hose. in\nplain and dropstitch with embroidered ankles.\nSpecial value.\n\n\n$50, 3 pairs for SIoo.",
#   'byline': '',
#   'bbox_list': [{'x0': 3523, 'y0': 4299, 'x1': 3922, 'y1': 4335},
#    {'x0': 3389, 'y0': 4349, 'x1': 4036, 'y1': 4470}],
#   'bbox': [3389, 4299, 4036, 4470],
#   'full_article_id': 55,
#   'id': '55_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [55],
#   'headline': '',
#   'article': 'The promoters of tariff medicine will\nhardly apply to Porto Rico for any before\nand after taking testimonials.',
#   'byline': '',
#   'bbox_list': [{'x0': 744, 'y0': 5731, 'x1': 1392, 'y1': 5832}],
#   'bbox': [744, 5731, 1392, 5832],
#   'full_article_id': 56,
#   'id': '56_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [72, 85, 66],
#   'headline': "We Are Agents for the ''standard'' Patterns.\nDepartm Frs floor\n\nA New Cook Book Free.",
#   'article': 'We viii tomorrow patrons New Cook Book\nHelen Louise Johnson entitled Ihe Enterpring\nHousekeeper" Ask for it in Housefurnishing Department',
#   'byline': '',
#   'bbox_list': [{'x0': 2782, 'y0': 5900, 'x1': 3932, 'y1': 5981},
#    {'x0': 3096, 'y0': 6000, 'x1': 3683, 'y1': 6050},
#    {'x0': 2743, 'y0': 6049, 'x1': 4031, 'y1': 6194}],
#   'bbox': [2743, 5900, 4031, 6194],
#   'full_article_id': 67,
#   'id': '67_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [80],
#   'headline': '',
#   'article': 'OIn order to avoid delays, on ac-\ncount of personal absence, letters to\nTHE STAR should not be Addressed\nto any individual connected with the\nOffice hut simply to THE STAR or to\nthe Editorial or Business Depart\nments according to tenor or purpose.',
#   'byline': '',
#   'bbox_list': [{'x0': 68, 'y0': 566, 'x1': 715, 'y1': 771}],
#   'bbox': [68, 566, 715, 771],
#   'full_article_id': 81,
#   'id': '81_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [98, 87],
#   'headline': "IOmorrOW, Saturday,\n\n\nSpecial Sale of\nWOmen's Trimmed Hats\nAt $500 Each.",
#   'article': "Pretty, stylish effects, suitable for\nimmediate wear. The latest shapes\nand colors and especially choice and\neffective trimmings.\n\n\nThough nodestly priced, these\nhats are in every way desirable and\nwe'll deserving of your inspection.\nMillinery Parlors-Second floor.",
#   'byline': '',
#   'bbox_list': [{'x0': 2738, 'y0': 2594, 'x1': 3355, 'y1': 2779},
#    {'x0': 2723, 'y0': 2788, 'x1': 3370, 'y1': 3137}],
#   'bbox': [2723, 2594, 3370, 3137],
#   'full_article_id': 88,
#   'id': '88_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'},
#  {'object_ids': [88],
#   'headline': '',
#   'article': 'First floor.',
#   'byline': '',
#   'bbox_list': [{'x0': 3419, 'y0': 4459, 'x1': 3564, 'y1': 4484}],
#   'bbox': [3419, 4459, 3564, 4484],
#   'full_article_id': 89,
#   'id': '89_1900-03-23_p6_sn83045462_00280655326_1900032301_0034.json'}]

# %%
# finally, we can inspect the image of the original page!
article_json['scan']

# The jp2 URL is the URL to the image, let's visualize it, this will take a bit of code
# Out:
# {'lccn': 'sn83045462',
#  'edition': 'ed-01',
#  'date': '1900-03-23',
#  'page': '6',
#  'jp2_url': 'https://chroniclingamerica.loc.gov/lccn/sn83045462/1900-03-23/ed-1/seq-6.jp2',
#  'ocr_text_url': 'https://chroniclingamerica.loc.gov/lccn/sn83045462/1900-03-23/ed-1/seq-6/ocr.txt',
#  'ocr_xml_url': 'https://chroniclingamerica.loc.gov/lccn/sn83045462/1900-03-23/ed-1/seq-6/ocr.xml',
#  'raw_data_loc': 'https://chroniclingamerica.loc.gov/data/batches/dlc_japanesechin_ver01/data/sn83045462/00280655326/1900032301/0034.jp2',
#  'height': 6363,
#  'width': 4850}

# %%
import requests
import cv2
import numpy as np
from matplotlib import pyplot as plt

def get_ca_scan_img(ca_url):
  img_download_session = requests.Session()
  response = img_download_session.get(ca_url)
  if response.status_code != 200:
    print(f'Error! {response.status_code}')
    print(f'Please verify that {ca_url} is a valid chronicling america url!')
    response.raise_for_status()

  data = response.content
  ca_img = cv2.imdecode(np.frombuffer(data, np.uint8), cv2.IMREAD_COLOR)
  return ca_img

# grab the url
ca_url = article_json['scan']['jp2_url']

#Get the image scan
ca_img = get_ca_scan_img(ca_url)

# Create a figure for the plot
plt.ion()
fig, ax = plt.subplots(1)
fig.set_size_inches(10, 10)

# Display image
ax.imshow(ca_img)
fig.suptitle('')

plt.show()

# %%
# with a bit more work, this routine can of course be expanded to the edition,
# that is, all pages in that newspaper on the same day

# %% [markdown]
# # Application: Spelling checking
#
# There is natural variation in the quality of the scans, and of OCR. It is
# straightforward to apply a spelling checker to any article. Here we briefly
# demonstrate how

# %%
# let's return to our article about shoes
shoes_article = dataset_article_level["1900"][5]['article']

# %%
# let's have a look
print(shoes_article)
# Out:
# Our stock of Shoes for young peo-
# pie comprises the best and most rep
# utable goods manufactured. All the
# latest and most improved shapes are
# represented, and both service and
# appearance were considered i'll their
# selection. We are also showing the
# Low Shoes for misses and children,
# in welt and turn sole, patent leather.
# vici kid and Russia calf; and the Nici
# Kid Spring Heel Shoes with patent
# tips, in extra sizes (21a to 51a). At
# tention is also called to our lines Of
# Infants Cacks and Soft Sole Shoes,
# in black, tans and other colors.
#
#
# The spring styles are ready.
#
#
# Youths Shoes sizes II to . Pair. 81 so to 50. 80
# Boys Shoes; sizes 21a 5h. Pair S15O to IS 90
# Misses Shoes; sizes II to p Pair .s15O to $500
# Chiliren's Shoes; sizes sls to 1Ol9 Pair
#
#
# S1.25 to s.. 90
# Infants Shoes: sizes 6 to s. Pair 81 90 to 81 II
# Infants Cacks; sizes 2 TO g. Pair soc. to 81 %
# Misses OYford5: sizes II to .. Pair. 81 50
# Misses Springfield Oxfords extra sizes, 2H to
# oi2. Falr -SZ.oo
# Chiiren's O1fords; sizes SA, to 1oR Pair. 81 SO
# Infants oxfords sizes to S. Pair. 81 80
# Third floor

# %% [markdown]
# The article text contains a few mistakes that we can correct. Looking at the text of the article, a few errors are apparent:
# 1. Some spelling mistakes exist, for example "peopie" in the first/second line
# 2. Some words are divided between multiple lines ("peo- pie", "rep utable", "At tention", etc).
# 3. Capitalization errors are somewhat common: "i'll", "...lines Of..."

# %%
# we have to download a spellchecking package
# !pip install symspellpy
# Out:
# Collecting symspellpy
#   Downloading symspellpy-6.7.7-py3-none-any.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 14.2 MB/s eta 0:00:00
# Collecting editdistpy>=0.1.3 (from symspellpy)
#   Downloading editdistpy-0.1.3.tar.gz (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 kB 5.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: editdistpy
#   Building wheel for editdistpy (pyproject.toml) ... done
#   Created wheel for editdistpy: filename=editdistpy-0.1.3-cp310-cp310-linux_x86_64.whl size=190885 sha256=10c72234324f7d391939edd9d6f62f08368ded73cf9e4bd41aa8eb6de57d5818
#   Stored in directory: /root/.cache/pip/wheels/88/6a/a6/a1283cc145323a1fb3d475bd158ee60b248ab1985230d266fc
# Successfully built editdistpy
# Installing collected packages: editdistpy, symspellpy
# Successfully installed editdistpy-0.1.3 symspellpy-6.7.7

# %%
# let's initialize the package
import pkg_resources
from symspellpy import SymSpell, Verbosity
import string

sym_spell = SymSpell(max_dictionary_edit_distance=2, prefix_length=7)
en_dict = pkg_resources.resource_filename('symspellpy', 'frequency_dictionary_en_82_765.txt')
sym_spell.load_dictionary(en_dict, term_index=0, count_index=1)
# Out:
# True

# %%
# we now create a few functions that take care of the issues flagged above

# thsese two functions implement spelling corrections
def check_word(word):
  no_punc_word = word.strip(string.punctuation)
  if len(no_punc_word) > 0:
    suggestions = sym_spell.lookup(no_punc_word, Verbosity.CLOSEST, max_edit_distance=1, include_unknown=True, transfer_casing=True)
  else:
    return word
  return word.replace(no_punc_word, suggestions[0].term)

def spell_check(text):
  lines = text.split('\n')
  checked_lines = []
  for line in lines:
    words = line.split(' ')
    checked_line = ' '.join([check_word(word) for word in words])
    checked_lines.append(checked_line)
  return '\n'.join(checked_lines)

# this function checks capitalization
def capitalization_check(text):
  lines = text.split('\n')
  checked_lines = []
  for line in lines:
    words = line.split(' ')
    for i in range(1, len(words)):
      if words[i-1][-1] in ['.', '!', '?']:
        words[i] = words[i].capitalize()
      else:
        no_punc_word = words[i].strip(string.punctuation)
        if no_punc_word in sym_spell.words and no_punc_word not in ['i', "i'll"]: # Check that the word is not a propper noun
          words[i] = words[i].replace(no_punc_word, no_punc_word.lower())

    checked_lines.append(' '.join(words))
  return '\n'.join(checked_lines)

# this functions corrects line breaks
def line_merge(text):
  lines = [l.split() for l in text.split('\n')]
  for i in range(len(lines) - 1):
    if len(lines[i]) == 0 or len(lines[i+1]) == 0:
      continue
    elif lines[i][-1][-1] == '-': # Automatically merge if a line ends with a hyphen
      lines[i][-1] = lines[i][-1][:-1] + lines[i+1][0]
      lines[i+1] = lines[i+1][1:]
    elif lines[i][-1].strip(string.punctuation).lower() not in sym_spell.words or lines[i+1][0].strip(string.punctuation).lower() not in sym_spell.words:
      if (lines[i][-1].strip(string.punctuation).lower() + lines[i+1][0].strip(string.punctuation).lower()) in sym_spell.words:
        lines[i][-1] += lines[i+1][0]
        lines[i+1] = lines[i+1][1:]

  return '\n'.join([' '.join(l) for l in lines])

# %%
# this functions implements all three methods
def postprocess(text):
  merged = line_merge(text)
  checked = spell_check(merged)
  capitalization_normalized = capitalization_check(checked)
  return capitalization_normalized

# %%
# now we can simple pass our text to the spelling correction routine!
print(postprocess(shoes_article))
# Out:
# Our stock of Shoes for young people
# comprises the best and most reputable
# goods manufactured. All the
# latest and most improved shapes are
# represented, and both service and
# appearance were considered i'll their
# selection. We are also showing the
# Low Shoes for misses and children,
# in welt and turn sole, patent leather.
# vice kid and Russia calf; and the Nice
# Kid Spring Heel Shoes with patent
# tips, in extra sizes (21a to 51a). Attention
# is also called to our lines Of
# Infants Cocks and Soft Sole Shoes,
# in black, tans and other color.
#
#
# The spring styles are ready.
#
#
# Youths Shoes sizes II to . Pair. 81 so to 50. 80
# Boys Shoes; sizes 21a 5h. Pair s15o to IS 90
# Misses Shoes; sizes II to a Pair .s15o to $500
# chiliren's Shoes; sizes sis to 1ol9 Pair
#
#
# s1.25 to a.. 90
# Infants Shoes: sizes a to a. Pair 81 90 to 81 II
# Infants Cocks; sizes a TO a. Pair soc. To 81 %Misses
# oyford5: sizes II to .. Pair. 81 50
# Misses Springfield Oxfords extra sizes, 2h to
# oil. Far -sz.oo
# chiiren's Oxfords; sizes A, to foR Pair. 81 SO
# Infants oxfords sizes to A. Pair. 81 80
# Third floor

# %% [markdown]
# Postprocessing can significantly help text, but can also create errors. If the dictionary does not include a correctly transcribed proper noun or anachronism, it can "correct" it to an erroneous word.
